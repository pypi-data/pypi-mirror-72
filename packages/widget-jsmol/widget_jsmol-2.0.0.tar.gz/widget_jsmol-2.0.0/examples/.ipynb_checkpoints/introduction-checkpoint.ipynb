# %% [markdown]
# # Introduction

# %% [markdown]
# ## Import the Jmol widget

# %%
from widget_jsmol import WidgetJmol

# %%
w = WidgetJmol()
display(w)
# Out:
# WidgetJmol()

# %% [markdown]
# ## Run Jmol script

# %%
w.script = "set background yellow"

# %% [markdown]
# ## Load local structure

# %%
w.structure = '/structure/test.pdb'

# %%
import IPython

# %%
IPython.display.display_html(w)
# Out:
# WidgetJmol(HTML='<div id="jmol_app144_appletinfotablediv" style="width:100%;height:100%;position:relative;font…

# %%
w.HTML
# Out:
# '<div id="jmol_app144_appletinfotablediv" style="width:100%;height:100%;position:relative;font-size:14px;text-align:left"> <img id="jmol_app144_waitimage" src="https://chemapps.stolaf.edu/jmol/jsmol/j2s/img/cursor_wait.gif" style="position: absolute; bottom: 10px; left: 10px; z-index: 9006; display: none;"><div id="jmol_app144_appletdiv" style="z-index: 9001; width: 100%; height: 100%; position: absolute; top: 0px; left: 0px; background-repeat: no-repeat; background-position: center center; display: block;"><script type="text/javascript">jmol_app144._cover(false)</script><canvas width="500" height="500" id="jmol_app144_canvas2d" style="width: 100%; height: 100%; z-index: 9002; cursor: default;"></canvas></div><div id="jmol_app144_2dappletdiv" style="position:absolute;width:100%;height:100%;overflow:hidden;display:none"></div><div id="jmol_app144_infotablediv" style="width: 100%; height: 100%; position: absolute; top: 0px; left: 0px; display: none;"><div id="jmol_app144_infoheaderdiv" style="height: 20px; width: 100%; background: yellow; display: none;"><span id="jmol_app144_infoheaderspan">Jmol._Canvas2D (Jmol) "jmol_app144"</span><span id="jmol_app144_infocheckboxspan" style="position:absolute;text-align:right;right:1px;"><a href="javascript:Jmol.showInfo(jmol_app144,false)">[x]</a></span></div><div id="jmol_app144_infodiv" style="position:absolute;top:20px;bottom:0px;width:100%;height:100%;overflow:auto"><div style="white-space: nowrap;"><span style="white-space: nowrap;">JSmol exec jmol_app144 loadClazz null</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">JSmol exec jmol_app144 start applet null</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Jmol JavaScript applet jmol_app144__784957366351741__ initializing</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Jmol getValue debug null</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Jmol getValue logLevel null</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Jmol getValue allowjavascript null</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">AppletRegistry.checkIn(jmol_app144__784957366351741__)</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">vwrOptions: </span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">{ "name":"jmol_app144","applet":true,"documentBase":"http://0.0.0.0:8889/lab/workspaces/auto-A","platform":"J.awtjs2d.Platform","fullName":"jmol_app144__784957366351741__","codePath":"https://chemapps.stolaf.edu/jmol/jsmol/j2s/","display":"jmol_app144_canvas2d","signedApplet":"true","appletReadyCallback":"Jmol._readyCallback","statusListener":"[J.appletjs.Jmol object]","MeasureCallback":"set_measure","syncId":"784957366351741","bgcolor":"#FFFFFF" }</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">setting document base to "http://0.0.0.0:8889/lab/workspaces/auto-A"</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">(C) 2015 Jmol Development</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Jmol Version: 14.30.2  2019-11-26 10:18</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">java.vendor: Java2Script (HTML5)</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">java.version: 2019-06-08 00:17:46 (JSmol/j2s)</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">os.name: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Access: ALL</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">memory: 0.0/0.0</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">processors a ...

# %%
w.HTML
# Out:
# '<div id="jmol_app144_appletinfotablediv" style="width:100%;height:100%;position:relative;font-size:14px;text-align:left"> <img id="jmol_app144_waitimage" src="https://chemapps.stolaf.edu/jmol/jsmol/j2s/img/cursor_wait.gif" style="position: absolute; bottom: 10px; left: 10px; z-index: 9006; display: none;"><div id="jmol_app144_appletdiv" style="z-index: 9001; width: 100%; height: 100%; position: absolute; top: 0px; left: 0px; background-repeat: no-repeat; background-position: center center; display: block;"><script type="text/javascript">jmol_app144._cover(false)</script><canvas width="500" height="500" id="jmol_app144_canvas2d" style="width: 100%; height: 100%; z-index: 9002; cursor: default;"></canvas></div><div id="jmol_app144_2dappletdiv" style="position:absolute;width:100%;height:100%;overflow:hidden;display:none"></div><div id="jmol_app144_infotablediv" style="width: 100%; height: 100%; position: absolute; top: 0px; left: 0px; display: none;"><div id="jmol_app144_infoheaderdiv" style="height: 20px; width: 100%; background: yellow; display: none;"><span id="jmol_app144_infoheaderspan">Jmol._Canvas2D (Jmol) "jmol_app144"</span><span id="jmol_app144_infocheckboxspan" style="position:absolute;text-align:right;right:1px;"><a href="javascript:Jmol.showInfo(jmol_app144,false)">[x]</a></span></div><div id="jmol_app144_infodiv" style="position:absolute;top:20px;bottom:0px;width:100%;height:100%;overflow:auto"><div style="white-space: nowrap;"><span style="white-space: nowrap;">JSmol exec jmol_app144 loadClazz null</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">JSmol exec jmol_app144 start applet null</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Jmol JavaScript applet jmol_app144__784957366351741__ initializing</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Jmol getValue debug null</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Jmol getValue logLevel null</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Jmol getValue allowjavascript null</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">AppletRegistry.checkIn(jmol_app144__784957366351741__)</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">vwrOptions: </span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">{ "name":"jmol_app144","applet":true,"documentBase":"http://0.0.0.0:8889/lab/workspaces/auto-A","platform":"J.awtjs2d.Platform","fullName":"jmol_app144__784957366351741__","codePath":"https://chemapps.stolaf.edu/jmol/jsmol/j2s/","display":"jmol_app144_canvas2d","signedApplet":"true","appletReadyCallback":"Jmol._readyCallback","statusListener":"[J.appletjs.Jmol object]","MeasureCallback":"set_measure","syncId":"784957366351741","bgcolor":"#FFFFFF" }</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">setting document base to "http://0.0.0.0:8889/lab/workspaces/auto-A"</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">(C) 2015 Jmol Development</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Jmol Version: 14.30.2  2019-11-26 10:18</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">java.vendor: Java2Script (HTML5)</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">java.version: 2019-06-08 00:17:46 (JSmol/j2s)</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">os.name: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">Access: ALL</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">memory: 0.0/0.0</span></div><div style="white-space: nowrap;"><span style="white-space: nowrap;">processors a ...

# %%
w
# Out:
# WidgetJmol(HTML='<div id="jmol_app144_appletinfotablediv" style="width:100%;height:100%;position:relative;font…

# %%
display(w)
# Out:
# WidgetJmol(HTML='<div id="jmol_app144_appletinfotablediv" style="width:100%;height:100%;position:relative;font…
